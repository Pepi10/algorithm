# %%
### 에라토스테네스의 체 ###
num = 10000

if num % 2 == 0:
    _min, _max = num + 1, 2 * num
else:
    _min, _max = num + 2, 2 * num

pri_li = [True] * (_max + 1)
pri_li[0] = False
pri_li[1] = False

for f in range(2, int(_max ** 0.5) + 1): #(O루트(N))
    if pri_li[f]:
        for s in range(f * f, _max + 1, f):
            pri_li[s] = False

# %%
print(sum(pri_li[_min:_max]), pri_li[_min:_max])
# Out:
# 1033 [False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, True, False, False, False, 
# ...

# %%
def search_prime(_min, _max):
    pri_li = [True] * (_max + 1)
    pri_li[0] = False
    pri_li[1] = False

    for f in range(2, int(_max ** 0.5) + 1):
        if pri_li[f]:
            for s in range(f * f, _max + 1, f):
                pri_li[s] = False
    _res = sum(pri_li[_min:_max])

    return _res

while True:
    num = int(input().rstrip())

    if num == 0:
        break
    elif num == 1:
        print(1)
    elif num % 2 == 0:
        print(search_prime(num + 1, 2 * num))
    else:
        print(search_prime(num + 2, 2 * num))
# Out:
# 1
# 4
# 3
# 21
# 135
# 1033
# 8392

# %% [markdown]
# ### Result

# %%
import sys
input = sys.stdin.readline

def search_prime(_min, _max):
    pri_li = [True] * (_max + 1)
    pri_li[0] = False
    pri_li[1] = False

    for f in range(2, int(_max ** 0.5) + 1):
        if pri_li[f]:
            for s in range(f * f, _max + 1, f):
                pri_li[s] = False
    _res = sum(pri_li[_min:_max])

    return _res

while True:
    num = int(input().rstrip())

    if num == 0:
        break
    elif num == 1:
        print(1)
    elif num % 2 == 0:
        print(search_prime(num + 1, 2 * num))
    else:
        print(search_prime(num + 2, 2 * num))
